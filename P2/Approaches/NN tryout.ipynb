# %%
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
def data_loading():
    """
    This function loads the training and test data, preprocesses it, removes the NaN values and interpolates the missing
    data using imputation

    Parameters
    ----------
    Returns
    ----------
    X_train: matrix of floats, training input with features
    y_train: array of floats, training output with labels
    X_test: matrix of floats: dim = (100, ?), test input with features
    """
    # Load training data
    train_df = pd.read_csv("train.csv")

    # print("Training data:")
    # print("Shape:", train_df.shape)
    # print(train_df.head(2))
    # print('\n')

    # Load test data
    test_df = pd.read_csv("test.csv")

    # print("Test data:")
    # print(test_df.shape)
    # print(test_df.head(2))

    # # Dummy initialization of the X_train, X_test and y_train
    # X_train = np.zeros_like(train_df.drop(['price_CHF'], axis=1))
    # y_train = np.zeros_like(train_df['price_CHF'])
    # X_test = np.zeros_like(test_df)

    # print(train_df)

    # Perform data preprocessing, imputation and extract X_train, y_train and X_test using mean values

    # Use interpolation for missing values. Interpolate cannot handle missing starting or end values. So fill these up with mean()

    # Why does this not work with RBF?
    
    ### Training set

    new_train_df = train_df.interpolate(method="akima")
    new_train_df = new_train_df.fillna(train_df.mean())

    # Encode season data

    binary_version_seasons = pd.get_dummies(new_train_df['season'])
    new_train_df = new_train_df.drop(columns=['season']).join(binary_version_seasons)

    y_train = new_train_df["price_CHF"]
    X_train = new_train_df.drop(columns=["price_CHF"])

    ### Test set

    new_test_df = test_df.interpolate(method="akima")
    new_test_df = new_test_df.fillna(new_test_df.mean())

    # Encode season data

    new_test_df = new_test_df.drop(columns=['season']).join(binary_version_seasons)

    X_test = new_test_df

    

    assert (X_train.shape[1] == X_test.shape[1]) and (X_train.shape[0] == y_train.shape[0]) and (
                X_test.shape[0] == 100), "Invalid data shape"
    return X_train, y_train, X_test

# %%
X_train, y_train, X_test = data_loading()
# Out:
# /tmp/ipykernel_544855/637515153.py:45: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   new_train_df = new_train_df.fillna(train_df.mean())
# /tmp/ipykernel_544855/637515153.py:58: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   new_test_df = new_test_df.fillna(new_test_df.mean())

# %%
# X_train = X_train.drop(columns='season')
# X_test = X_test.drop(columns='season')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 X_train = X_train.drop(columns='season')
#       2 X_test = X_test.drop(columns='season')
#
# File /usr/lib64/python3.11/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File /usr/lib64/python3.11/site-packages/pandas/core/frame.py:5396, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5248 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5249 def drop(  # type: ignore[override]
#    5250     self,
#    (...)
#    5257     errors: IgnoreRaise = "raise",
#    5258 ) -> DataFrame | None:
#    5259     """
#    5260     Drop specified labels from rows or columns.
#    5261
#    (...)
#    5394             weight  1.0     0.8
#    5395     """
# -> 5396     return super().drop(
#    5397         labels=labels,
#    5398         axis=axis,
#    5399         index=index,
#    5400         columns=columns,
#    5401         level=level,
#    5402         inplace=inplace,
#    5403         errors=errors,
#    5404     )
#
# File /usr/lib64/python3.11/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File /usr/lib64/python3.11/site-packages/pandas/core/generic.py:4505, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503 for axis, labels in axes.items():
#    4504     if labels is not None:
# -> 4505         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4507 if inplace:
#    4508     self._update_inplace(obj)
#
# File /usr/lib64/python3.11/site-packages/pandas/core/generic.py:4546, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4544         new_axis = axis.drop(labels, level=level, errors=errors)
#    4545     else:
# -> 4546         new_axis = axis.drop(labels, errors=errors)
#    4547     indexer = axis.get_indexer(new_axis)
#    4549 # Case for non-unique axis
#    4550 else:
#
# File /usr/lib64/python3.11/site-packages/pandas/core/indexes/base.py:6977, in Index.drop(self, labels, errors)
#    6975 if mask.any():
#    6976     if errors != "ignore":
# -> 6977         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6978     indexer = indexer[~mask]
#    6979 return self.delete(indexer)
#
# KeyError: "['season'] not found in axis"

# %%
X_train.head()
# Out:
#    price_AUS  price_CZE  price_GER  price_ESP  price_FRA  price_UK  price_ITA  \
# 0  -0.665411  -1.686248  -1.748076  -3.666005  -2.914028 -1.822720  -3.931031
# 1  -0.665411  -2.132377  -2.054363  -3.295697  -4.104759 -1.826021  -4.033859
# 2  -2.101937  -1.910282  -1.828418  -3.388777  -4.043980 -2.034409  -4.073850
# 3  -2.098475  -1.903834  -1.556678  -3.588235  -3.978186 -2.214720  -4.018620
# 4  -1.969687  -1.697257  -1.331049  -3.733160  -3.911096 -2.388092  -4.093946
#
#    price_POL  price_SVK  autumn  spring  summer  winter
# 0  -0.296811  -3.238197       0       1       0       0
# 1  -0.296811  -3.212894       0       0       1       0
# 2  -0.296811  -3.114061       1       0       0       0
# 3  -2.330803  -2.963840       0       0       0       1
# 4  -2.217360  -2.796754       0       1       0       0

# %%
y_train.head()
# Out:
# 0    9.644028
# 1    7.246061
# 2    7.620085
# 3    8.411894
# 4    8.926884
# Name: price_CHF, dtype: float64

# %%
X_test.head()
# Out:
#    price_AUS  price_CZE  price_GER  price_ESP  price_FRA  price_UK  price_ITA  \
# 0  -1.330600   0.472985   0.707957  -4.009095  -1.136441 -0.596703  -3.304914
# 1  -1.184837   0.358019   0.741609  -3.199028  -1.069695 -0.579515  -1.420091
# 2  -1.116459   0.354504   0.780460  -3.338948  -1.053149 -0.586339  -1.331542
# 3  -1.090106   0.353066   0.833429  -3.287990  -1.322626 -0.628873  -1.304240
# 4  -1.073283   0.269644   0.771367  -3.245495  -1.362051 -0.717914  -1.341538
#
#    price_POL  price_SVK  autumn  spring  summer  winter
# 0   3.298693   1.921886       0       1       0       0
# 1   3.238307   1.972984       0       0       1       0
# 2   3.207398   2.020570       1       0       0       0
# 3   3.159858   2.064163       0       0       0       1
# 4   3.205007   2.101199       0       1       0       0

# %%
sns.pairplot(X_train.sample(n=100)[['price_AUS', 'price_CZE', 'price_GER', 'price_ESP', 'price_UK', 'price_ITA', 'price_POL', 'price_SVK', 'autumn', 'spring', 'summer', 'winter']])

# %%
#--------MODEL BUILDING
num_params = len(X_train.keys())
print(num_params)
model = tf.keras.Sequential([
    tf.keras.layers.InputLayer([num_params], name="Input_Layer"),
    tf.keras.layers.Dense(50, activation='relu', name="dense_01"),
    tf.keras.layers.Dense(50, activation='relu', name="dense_02"),
    # 1 node in the output for the median_house_vale
    tf.keras.layers.Dense(1, name="Output_Layer")
  ])

learning_rate = 0.0001
model.compile(optimizer=tf.keras.optimizers.RMSprop(learning_rate),
              # loss function to minimize
              loss=tf.keras.losses.MeanSquaredError(),
              # list of metrics to monitor
              metrics=['mae',])

model.summary()
# Out:
# 13
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_01 (Dense)            (None, 50)                700
#
#  dense_02 (Dense)            (None, 50)                2550
#
#  Output_Layer (Dense)        (None, 1)                 51
#
# =================================================================
# Total params: 3,301
# Trainable params: 3,301
# Non-trainable params: 0
# _________________________________________________________________

# %%
# FIT/TRAIN model on training data
history = model.fit(X_train, y_train,
                    batch_size=20,
                    epochs=100,
                    validation_split=0.2,
                    # validation_data=X_test,
                    verbose=1)
# Out:
# Epoch 1/100
# 36/36 [==============================] - 0s 5ms/step - loss: 36.9557 - mae: 5.4310 - val_loss: 36.8862 - val_mae: 5.6053
# Epoch 2/100
# 36/36 [==============================] - 0s 3ms/step - loss: 29.9336 - mae: 4.8306 - val_loss: 29.6581 - val_mae: 4.9172
# Epoch 3/100
# 36/36 [==============================] - 0s 3ms/step - loss: 24.2546 - mae: 4.2735 - val_loss: 23.3768 - val_mae: 4.2197
# Epoch 4/100
# 36/36 [==============================] - 0s 3ms/step - loss: 19.4058 - mae: 3.7376 - val_loss: 18.1686 - val_mae: 3.5634
# Epoch 5/100
# 36/36 [==============================] - 0s 3ms/step - loss: 15.4473 - mae: 3.2353 - val_loss: 13.9146 - val_mae: 3.0097
# Epoch 6/100
# 36/36 [==============================] - 0s 3ms/step - loss: 12.0258 - mae: 2.8113 - val_loss: 10.3979 - val_mae: 2.5920
# Epoch 7/100
# 36/36 [==============================] - 0s 3ms/step - loss: 9.0988 - mae: 2.4256 - val_loss: 7.5228 - val_mae: 2.2225
# Epoch 8/100
# 36/36 [==============================] - 0s 3ms/step - loss: 6.6331 - mae: 2.0748 - val_loss: 5.2135 - val_mae: 1.8492
# Epoch 9/100
# 36/36 [==============================] - 0s 3ms/step - loss: 4.5963 - mae: 1.7259 - val_loss: 3.4176 - val_mae: 1.4820
# Epoch 10/100
# 36/36 [==============================] - 0s 4ms/step - loss: 3.0284 - mae: 1.4092 - val_loss: 2.1653 - val_mae: 1.1502
# Epoch 11/100
# 36/36 [==============================] - 0s 7ms/step - loss: 1.9907 - mae: 1.1411 - val_loss: 1.5160 - val_mae: 0.9272
# Epoch 12/100
# 36/36 [==============================] - 0s 4ms/step - loss: 1.4329 - mae: 0.9489 - val_loss: 1.2537 - val_mae: 0.8370
# Epoch 13/100
# 36/36 [==============================] - 0s 4ms/step - loss: 1.1928 - mae: 0.8437 - val_loss: 1.1742 - val_mae: 0.8066
# Epoch 14/100
# 36/36 [==============================] - 0s 4ms/step - loss: 1.0877 - mae: 0.8028 - val_loss: 1.1181 - val_mae: 0.7844
# Epoch 15/100
# 36/36 [==============================] - 0s 4ms/step - loss: 1.0202 - mae: 0.7754 - val_loss: 1.0692 - val_mae: 0.7608
# Epoch 16/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.9610 - mae: 0.7559 - val_loss: 1.0241 - val_mae: 0.7375
# Epoch 17/100
# 36/36 [==============================] - 0s 5ms/step - loss: 0.9167 - mae: 0.7365 - val_loss: 0.9854 - val_mae: 0.7148
# Epoch 18/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.8737 - mae: 0.7206 - val_loss: 0.9608 - val_mae: 0.6962
# Epoch 19/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.8349 - mae: 0.7057 - val_loss: 0.9446 - val_mae: 0.6857
# Epoch 20/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.7982 - mae: 0.6894 - val_loss: 0.9216 - val_mae: 0.6686
# Epoch 21/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.7656 - mae: 0.6780 - val_loss: 0.8946 - val_mae: 0.6503
# Epoch 22/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.7408 - mae: 0.6671 - val_loss: 0.8821 - val_mae: 0.6417
# Epoch 23/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.7147 - mae: 0.6560 - val_loss: 0.8760 - val_mae: 0.6314
# Epoch 24/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6907 - mae: 0.6461 - val_loss: 0.8778 - val_mae: 0.6238
# Epoch 25/100
# 36/36 [==============================] - 0s 5ms/step - loss: 0.6679 - mae: 0.6355 - val_loss: 0.8609 - val_mae: 0.6133
# Epoch 26/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6523 - mae: 0.6279 - val_loss: 0.8546 - val_mae: 0.6076
# Epoch 27/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6314 - mae: 0.6176 - val_loss: 0.8530 - val_mae: 0.5994
# Epoch 28/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.6162 - mae: 0.6083 - val_loss: 0.8511 - val_mae: 0.5938
# Epoch 29/100
# 36/36 [==============================] - 0s 5ms/step - loss: 0.5990 - mae: 0.5989 - val_loss: 0.8419 - val_mae: 0.5894
# Epoch 30/100
# 36/36 [==============================] - 0s 6ms/step - loss: 0.5842 - mae: 0.5920 - val_loss: 0.8455 - val_mae: 0.5848
# Epoch 31/100
# 36/36 [==============================] - 0s 5ms/step - loss: 0.5671 - mae: 0.5810 - val_loss: 0.8419 - val_mae: 0.5836
# Epoch 32/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.5567 - mae: 0.5767 - val_loss: 0.8515 - val_mae: 0.5800
# Epoch 33/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.5420 - mae: 0.5680 - val_loss: 0.8446 - val_mae: 0.5754
# Epoch 34/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.5319 - mae: 0.5617 - val_loss: 0.8373 - val_mae: 0.5733
# Epoch 35/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.5187 - mae: 0.5542 - val_loss: 0.8571 - val_mae: 0.5730
# Epoch 36/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.5120 - mae: 0.5505 - val_loss: 0.8369 - val_mae: 0.5678
# Epoch 37/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.5001 - mae: 0.5409 - val_loss: 0.8379 - val_mae: 0.5654
# Epoch 38/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.4897 - mae: 0.5357 - val_loss: 0.8383 - val_mae: 0.5589
# Epoch 39/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.4774 - mae: 0.5299 - val_loss: 0.8508 - val_mae: 0.5581
# Epoch 40/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.4690 - mae: 0.5210 - val_loss: 0.8351 - val_mae: 0.5550
# Epoch 41/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.4604 - mae: 0.5179 - val_loss: 0.8368 - val_mae: 0.5532
# Epoch 42/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.4539 - mae: 0.5118 - val_loss: 0.8423 - val_mae: 0.5488
# Epoch 43/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.4438 - mae: 0.5044 - val_loss: 0.8367 - val_mae: 0.5583
# Epoch 44/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.4378 - mae: 0.4994 - val_loss: 0.8440 - val_mae: 0.5378
# Epoch 45/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.4331 - mae: 0.4950 - val_loss: 0.8407 - val_mae: 0.5431
# Epoch 46/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.4240 - mae: 0.4888 - val_loss: 0.8431 - val_mae: 0.5348
# Epoch 47/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.4170 - mae: 0.4854 - val_loss: 0.8385 - val_mae: 0.5449
# Epoch 48/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.4113 - mae: 0.4805 - val_loss: 0.8420 - val_mae: 0.5411
# Epoch 49/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.4084 - mae: 0.4773 - val_loss: 0.8413 - val_mae: 0.5310
# Epoch 50/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.3983 - mae: 0.4723 - val_loss: 0.8599 - val_mae: 0.5385
# Epoch 51/100
# 36/36 [==============================] - 0s 6ms/step - loss: 0.3959 - mae: 0.4671 - val_loss: 0.8487 - val_mae: 0.5302
# Epoch 52/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.3874 - mae: 0.4645 - val_loss: 0.8558 - val_mae: 0.5296
# Epoch 53/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.3832 - mae: 0.4582 - val_loss: 0.8556 - val_mae: 0.5225
# Epoch 54/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.3799 - mae: 0.4537 - val_loss: 0.8480 - val_mae: 0.5266
# Epoch 55/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.3742 - mae: 0.4507 - val_loss: 0.8448 - val_mae: 0.5509
# Epoch 56/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.3716 - mae: 0.4507 - val_loss: 0.8557 - val_mae: 0.5171
# Epoch 57/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.3667 - mae: 0.4456 - val_loss: 0.8494 - val_mae: 0.5211
# Epoch 58/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.3639 - mae: 0.4422 - val_loss: 0.8478 - val_mae: 0.5382
# Epoch 59/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.3602 - mae: 0.4401 - val_loss: 0.8518 - val_mae: 0.5300
# Epoch 60/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.3560 - mae: 0.4350 - val_loss: 0.8547 - val_mae: 0.5176
# Epoch 61/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.3530 - mae: 0.4332 - val_loss: 0.8545 - val_mae: 0.5229
# Epoch 62/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.3483 - mae: 0.4316 - val_loss: 0.8648 - val_mae: 0.5213
# Epoch 63/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.3456 - mae: 0.4274 - val_loss: 0.8558 - val_mae: 0.5153
# Epoch 64/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.3429 - mae: 0.4267 - val_loss: 0.8638 - val_mae: 0.5152
# Epoch 65/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.3407 - mae: 0.4237 - val_loss: 0.8585 - val_mae: 0.5185
# Epoch 66/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.3365 - mae: 0.4225 - val_loss: 0.8612 - val_mae: 0.5160
# Epoch 67/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.3344 - mae: 0.4192 - val_loss: 0.8680 - val_mae: 0.5154
# Epoch 68/100
# 36/36 [==============================] - 0s 6ms/step - loss: 0.3338 - mae: 0.4167 - val_loss: 0.8597 - val_mae: 0.5211
# Epoch 69/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.3302 - mae: 0.4136 - val_loss: 0.8577 - val_mae: 0.5194
# Epoch 70/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.3275 - mae: 0.4148 - val_loss: 0.8608 - val_mae: 0.5179
# Epoch 71/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.3271 - mae: 0.4137 - val_loss: 0.8609 - val_mae: 0.5142
# Epoch 72/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.3234 - mae: 0.4112 - val_loss: 0.8633 - val_mae: 0.5160
# Epoch 73/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.3206 - mae: 0.4085 - val_loss: 0.8744 - val_mae: 0.5211
# Epoch 74/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.3209 - mae: 0.4067 - val_loss: 0.8666 - val_mae: 0.5109
# Epoch 75/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.3178 - mae: 0.4057 - val_loss: 0.8590 - val_mae: 0.5265
# Epoch 76/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.3151 - mae: 0.4050 - val_loss: 0.8788 - val_mae: 0.5117
# Epoch 77/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.3136 - mae: 0.4041 - val_loss: 0.8713 - val_mae: 0.5108
# Epoch 78/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.3120 - mae: 0.4026 - val_loss: 0.8695 - val_mae: 0.5088
# Epoch 79/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.3093 - mae: 0.3984 - val_loss: 0.8644 - val_mae: 0.5102
# Epoch 80/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.3077 - mae: 0.3986 - val_loss: 0.8599 - val_mae: 0.5234
# Epoch 81/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.3092 - mae: 0.3993 - val_loss: 0.8658 - val_mae: 0.5085
# Epoch 82/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.3051 - mae: 0.3980 - val_loss: 0.8795 - val_mae: 0.5095
# Epoch 83/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.3036 - mae: 0.3947 - val_loss: 0.8669 - val_mae: 0.5220
# Epoch 84/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.3045 - mae: 0.3949 - val_loss: 0.8651 - val_mae: 0.5117
# Epoch 85/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.3028 - mae: 0.3959 - val_loss: 0.8719 - val_mae: 0.5022
# Epoch 86/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.2996 - mae: 0.3918 - val_loss: 0.8665 - val_mae: 0.5087
# Epoch 87/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.3002 - mae: 0.3928 - val_loss: 0.8645 - val_mae: 0.5087
# Epoch 88/100
# 36/36 [==============================] - 0s 6ms/step - loss: 0.2982 - mae: 0.3914 - val_loss: 0.8684 - val_mae: 0.5055
# Epoch 89/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.2981 - mae: 0.3926 - val_loss: 0.8753 - val_mae: 0.5068
# Epoch 90/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.2947 - mae: 0.3861 - val_loss: 0.8669 - val_mae: 0.5103
# Epoch 91/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.2963 - mae: 0.3886 - val_loss: 0.8795 - val_mae: 0.5079
# Epoch 92/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.2936 - mae: 0.3878 - val_loss: 0.8738 - val_mae: 0.5039
# Epoch 93/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.2919 - mae: 0.3866 - val_loss: 0.8645 - val_mae: 0.5127
# Epoch 94/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.2916 - mae: 0.3868 - val_loss: 0.8751 - val_mae: 0.5003
# Epoch 95/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.2905 - mae: 0.3846 - val_loss: 0.8757 - val_mae: 0.5023
# Epoch 96/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.2901 - mae: 0.3867 - val_loss: 0.8770 - val_mae: 0.5025
# Epoch 97/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.2840 - mae: 0.3811 - val_loss: 0.8818 - val_mae: 0.5193
# Epoch 98/100
# 36/36 [==============================] - 0s 3ms/step - loss: 0.2887 - mae: 0.3835 - val_loss: 0.8696 - val_mae: 0.5047
# Epoch 99/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.2849 - mae: 0.3830 - val_loss: 0.8705 - val_mae: 0.5067
# Epoch 100/100
# 36/36 [==============================] - 0s 4ms/step - loss: 0.2859 - mae: 0.3814 - val_loss: 0.8631 - val_mae: 0.5104

# %%
#--------MONITOR
# Plot training & validation loss values
fig = plt.figure(figsize=(12,9))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validate'], loc='upper left')
plt.show()
